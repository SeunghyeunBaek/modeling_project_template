# %%
from matplotlib import pyplot as plt
import cv2

# %%
img = cv2.imread('/workspace/shbaek/template_project/image_classification/data/99_sampledataset/val/images/0_372.png', cv2.IMREAD_GRAYSCALE)

# %%
import numpy as np
plt.imshow(img)
